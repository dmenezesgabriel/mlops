# %% [markdown]
# # NYC Taxi Demand Forecasting
#
# This project turns NYC TLC yellow taxi trip records into local, reproducible demand forecasting pipelines.
#
# Start with [[problem-framing|Problem Framing]], then follow [[dataset-collection|Dataset Collection]] and [[event-logs-to-supervised-learning|Event Logs To Supervised Learning]].
